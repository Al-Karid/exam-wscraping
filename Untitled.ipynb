# %%
import numpy as np
import pandas as pd

# %%
all_data_1 = pd.read_csv("data_03_full_01.csv")
all_data_2 = pd.read_csv("data_03_full_02.csv")

# %%
all_data = pd.concat([all_data_1, all_data_2])

# %%
all_data.shape
# Out:
# (10337, 4)

# %%
all_data[all_data.columns[[0,2]]].groupby("noms").mean().sort_values("remuneration", ascending=False)
# Out:
#                             remuneration
# noms
# gauvain-raphael            164275.285714
# lardet-frederique          138423.833333
# bachelier-florian          131384.857143
# fuchs-bruno                126945.000000
# laqhila-mohamed            125864.200000
# marilossian-jacques        118273.000000
# cazeneuve-jean-rene        117352.750000
# vallaud-boris              109078.700000
# michels-thierry            105837.714286
# melenchon-jean-luc          93026.142857
# baichere-didier             88690.833333
# paris-didier                83004.294118
# borowczyk-julien            80028.571429
# fauvergue-jean-michel       77985.875000
# mattei-jean-paul            76600.625000
# granjus-florence            76260.857143
# millienne-bruno             74660.700000
# rixain-marie-pierre         73403.857143
# moutchou-naima              71442.857143
# hammouche-brahim            69127.857143
# de-rugy-francois            69021.400000
# gerard-raphael              69000.666667
# ...
